# %%
# %matplotlib inline
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
county_color={}

# %%
students_county2016= pd.read_csv("county_grade.csv")
students_county2016.head()
# Out:
#    Unnamed: 0  Fiscal Year    County     KG     PS      1      2      3  \
# 0           0         2018   Arizona  79492  14153  80335  81141  84873
# 1           1         2018    Apache    733    138    788    765    819
# 2           2         2018   Cochise   1260    260   1312   1286   1356
# 3           3         2018  Coconino   1287    252   1352   1253   1423
# 4           4         2018      Gila    585    162    562    608    623
#
#        4      5      6      7      8      9     10     11     12    Total
# 0  88061  88794  87248  86307  86025  86029  83806  78194  83801  1108259
# 1    789    795    853    900    904    816    827    710    846    10683
# 2   1464   1420   1420   1480   1450   1660   1579   1277   1348    18572
# 3   1392   1474   1372   1449   1416   1488   1479   1386   1339    18362
# 4    612    586    510    569    579    589    523    419    476     7403

# %%
#color_scheme = {'Gold':'#FFD700', 'Light Sky Blue':'#87CEFA', 'Light Coral':'#F08080'}
#county_color = {'9': color_scheme['Gold'], '10': color_scheme['Light Sky Blue'], '11': color_scheme['Light Coral']}

# %%
HS_county2016 = students_county2016[['8','10','12']]
HS_county2016 = HS_county2016.apply(pd.to_numeric)
HS_county_join2016 = students_county2016[['County']].join(HS_county2016)
HS_county_join2016
# Out:
#         County      8     10     12
# 0      Arizona  86025  83806  83801
# 1       Apache    904    827    846
# 2      Cochise   1450   1579   1348
# 3     Coconino   1416   1479   1339
# 4         Gila    579    523    476
# 5       Graham    435    455    370
# 6     Greenlee    113    127     94
# 7       La Paz    196    176    132
# 8     Maricopa  56657  55815  56067
# 9       Mohave   1829   1650   1553
# 10      Navajo   1338   1438   1246
# 11        Pima  11496  10842  11765
# 12       Pinal   3852   3077   2973
# 13  Santa Cruz    806    837    872
# 14     Yavapai   1952   1901   1657
# 15        Yuma   2966   3029   2820

# %%
HS_county_join2016['Totals'] = HS_county2016[HS_county2016.columns].sum(axis=1)
HS_county_join2016
# Out:
#         County      8     10     12  Totals
# 0      Arizona  86025  83806  83801  253632
# 1       Apache    904    827    846    2577
# 2      Cochise   1450   1579   1348    4377
# 3     Coconino   1416   1479   1339    4234
# 4         Gila    579    523    476    1578
# 5       Graham    435    455    370    1260
# 6     Greenlee    113    127     94     334
# 7       La Paz    196    176    132     504
# 8     Maricopa  56657  55815  56067  168539
# 9       Mohave   1829   1650   1553    5032
# 10      Navajo   1338   1438   1246    4022
# 11        Pima  11496  10842  11765   34103
# 12       Pinal   3852   3077   2973    9902
# 13  Santa Cruz    806    837    872    2515
# 14     Yavapai   1952   1901   1657    5510
# 15        Yuma   2966   3029   2820    8815

# %%
#Lists

cig = []

# %%
for i in range(len(HS_county_join2016['Totals'])):
    cig.append((HS_county_join2016.iloc[i, 4 ]*.07))
HS_county_join2016['Cigarettes'] = cig
HS_county_join2016
# Out:
#         County      8     10     12  Totals  Cigarettes
# 0      Arizona  86025  83806  83801  253632    17754.24
# 1       Apache    904    827    846    2577      180.39
# 2      Cochise   1450   1579   1348    4377      306.39
# 3     Coconino   1416   1479   1339    4234      296.38
# 4         Gila    579    523    476    1578      110.46
# 5       Graham    435    455    370    1260       88.20
# 6     Greenlee    113    127     94     334       23.38
# 7       La Paz    196    176    132     504       35.28
# 8     Maricopa  56657  55815  56067  168539    11797.73
# 9       Mohave   1829   1650   1553    5032      352.24
# 10      Navajo   1338   1438   1246    4022      281.54
# 11        Pima  11496  10842  11765   34103     2387.21
# 12       Pinal   3852   3077   2973    9902      693.14
# 13  Santa Cruz    806    837    872    2515      176.05
# 14     Yavapai   1952   1901   1657    5510      385.70
# 15        Yuma   2966   3029   2820    8815      617.05

# %%
HS_county_join2016.to_csv('AZ_8_10_12_2017.csv',index=False)

# %%
#Not Necessary
fig = plt.figure(figsize=(10,8))
barWidth = 0.3

mj = [4660,11933,12219]
alcohol = [6300,28299,28360]
e_cig=[5350,8779,10592]
bars1 = ('8th Grade', '10th Grade','12th Grade')

y1 = np.arange(len(bars1))
y2= [x + barWidth for x in y1]
y3= [x + barWidth for x in y2]
 
# Create bars
plt.bar(y1, mj, width = barWidth, color = (0.3,0.1,0.4,0.6), edgecolor='black', label='Marijuana')
plt.bar(y2, alcohol, width = barWidth, color = (0.3,0.5,0.4,0.6), edgecolor='black', label='Alcohol')
plt.bar(y3, e_cig, width = barWidth, color = (0.1,0.1,0.3,0.5), edgecolor='black', label='Ecigarettes')
 
# Create names on the x-axis
plt.xticks([y + (.95*barWidth) for y in range(len(bars1))], bars1)
plt.title('Substance abuse in AZ: Age 12-17 (National Average)')
plt.xlabel('Substance')
plt.ylabel('Population')
plt.legend()

#Save Figure
fig.savefig('Substance abuse in AZ: Age 12-17 (National Average) .png') 
# Show graphic
plt.show()
