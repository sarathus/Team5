# %%
import pandas as pd
import csv
import numpy

# %%
population_students= pd.read_csv("population_grade.csv")
population_students.head()
# Out:
#    Unnamed: 0  Fiscal Year                                       LEA Name  \
# 0           0         2018                A Center for Creative Education
# 1           1         2018  AIBT Non-Profit Charter High School - Phoenix
# 2           2         2018      AIBT Non-Profit Charter High School, Inc.
# 3           3         2018                        ASU Preparatory Academy
# 4           4         2018                        ASU Preparatory Academy
#
#    LEA Entity ID                                        School Name  \
# 0          79457  Verde Valley Montessori School - A Center for ...
# 1          79053                           RCB Medical Arts Academy
# 2         449790                    RCB College Preparatory Academy
# 3          89949        ASU Preparatory Academy- Phoenix Elementary
# 4          90273          Phoenix Collegiate Academy Charter School
#
#    School Entity ID PS  KG   1   2  ...   4   5   6   7   8  9  10  11  12  \
# ...

# %%
ninth_twelft_grade = population_students[['9','10','11','12']]
total_grades = ninth_twelft_grade.replace('*','0')

total_grades = total_grades[(total_grades[['9','10','11','12']] != '0').all(axis=1)]
total_grades = total_grades.apply(pd.to_numeric)

# %%
total_students_grade = total_grades.sum()

# %%
pd.DataFrame(total_students_grade, columns=['Total'])
# Out:
#     Total
# 9   83053
# 10  80662
# 11  73799
# 12  73846
